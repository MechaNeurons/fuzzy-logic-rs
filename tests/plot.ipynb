# %%
from matplotlib import pyplot as plt
import numpy as np
x = np.linspace(0,1,30)
out = [0.0038762824678766354, 0.010812242231392787, 0.028250783099228707, 0.06368532160995384, 0.1122684010999407, 0.15241202541094837, 0.17402872196761476, 0.1835205399919445, 0.18858801257771476, 0.19441847841751667, 0.2049998244384952, 0.2207763794770655, 0.23544127610463061, 0.24388342543377345, 0.24711794357502692, 0.24711794357502703, 0.24388342543377345, 0.23544127610463061, 0.2207763794770655, 0.20499982443849518, 0.19441847841751667, 0.18858801257771474, 0.1835205399919445, 0.1740287219676147, 0.15241202541094837, 0.11226840109994063, 0.06368532160995377, 0.028250783099228707, 0.01081224223139278, 0.0038762824678766354]
original = x*(1-x)
plt.figure()
plt.plot(x,out,"r--",label="Approximated")
plt.plot(x,original,"g",label = "Original")
plt.grid()
plt.legend()
plt.xlabel("X")
plt.ylabel("Y")
plt.title("f(x) = x(1-x)")
# plt.show()
# Out:
# Text(0.5, 1.0, 'f(x) = x(1-x)')
